# %% [markdown]
# Title: **Assignment 1: Study of Deep learning Packages: Tensorflow, Keras, Theano and PyTorch.
# Document the distinct features and functionality of the packages.**<br>

# %%
import numpy as np

# %% [markdown]
# **1. Tensorflow**

# %%
# !pip install tensorflow
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.6.2 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.3 which is incompatible.
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.1
#     Uninstalling numpy-1.20.1:
#       Successfully uninstalled numpy-1.20.1
# ...

# %% [markdown]
# **2. Keras**

# %%
from keras import datasets
# Load MNIST datasets from keras
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# **3. Theano**

# %%
# !pip install Theano

# %% [markdown]
# **4. PyTorch**

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu115
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu115
# ...
#   Obtaining dependency information for torchaudio from https://files.pythonhosted.org/packages/6b/ba/0e26883fd90f280452bed7edc7906ef9253255f395702751f65fa02afb5c/torchaudio-2.1.0-cp310-cp310-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 2.3/2.3 MB 6.2 MB/s eta 0:00:00
# ...

# %%
import torch
import torch.nn as nn

# %%
print(torch.__version__)
# Out:
# 2.1.0+cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %%
'''

## 🔷 PRACTICAL NAME

**“Study of Deep Learning Packages: TensorFlow, Keras, Theano, and PyTorch – Document the Distinct Features and Functionality of the Packages.”**

---

## 🔹 AIM

To study and understand the features, installation, and functionality of popular deep learning libraries — TensorFlow, Keras, Theano, and PyTorch — and to compare their distinct characteristics.

---

## 🔹 THEORY (As per your practical code)

### 1. **TensorFlow**

* **Installed using:** `!pip install tensorflow`
* **Developed by:** Google Brain Team, 2015
* **Type:** Open-source, end-to-end deep learning platform
* **Language:** Python (with C++ backend)
* **Core Idea:** Represents computations as *dataflow graphs*.

  * Nodes → Operations
  * Edges → Multidimensional data arrays (Tensors)

**Functionality:**

* Supports **CPU and GPU** computation.
* Provides **TensorBoard** for training visualization.
* Offers **TensorFlow Lite** (mobile), **TensorFlow.js** (web), and **TensorFlow Extended (TFX)** for production ML pipelines.
* Includes high-level Keras API for easy model building.

**Code relation:** Your notebook installs TensorFlow and prepares to use datasets with it.

---

### 2. **Keras**

* **Imported in code as:**

  ```python
  from keras import datasets
  (train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
  ```
* **Developed by:** François Chollet (now part of TensorFlow)
* **Type:** High-level neural network API
* **Core Idea:** Makes deep learning simple, readable, and modular.
* **Backend Engines:** TensorFlow (default), Theano (older), CNTK (deprecated)

**Functionality:**

* Uses **Sequential** or **Functional API** for defining models.
* Contains built-in layers (Dense, Conv2D, etc.), loss functions, and optimizers.
* Offers **dataset utilities** like MNIST, CIFAR-10.
* Rapid prototyping and debugging with minimal code.

**Code relation:** You used Keras to load and test the MNIST dataset — a classic image dataset used for deep learning model testing.

---

### 3. **Theano**

* **Installed using:** `!pip install Theano`
* **Developed by:** MILA Lab, University of Montreal (2008)
* **Type:** Low-level numerical computation library
* **Core Idea:** Compiles symbolic mathematical expressions into optimized C or CUDA code.
* **Status:** Discontinued (since 2017), but foundational to modern frameworks.

**Functionality:**

* Introduced **symbolic differentiation** (automatic gradient computation).
* Performs **graph optimization** for better speed.
* Runs on both **CPU and GPU**.
* Basis for early Keras backends.

**Code relation:** Installation command verifies understanding of how older frameworks paved the way for TensorFlow and PyTorch.

---

### 4. **PyTorch**

* **Installed using:**

  ```python
  # !pip3 install torch torchvision torchaudio
  import torch
  import torch.nn as nn
  ```
* **Developed by:** Facebook’s AI Research Lab (FAIR), 2016
* **Type:** Dynamic computation framework
* **Core Idea:** “Define-by-run” — graphs are created during execution.

**Functionality:**

* **Dynamic computation graph** allows on-the-fly model definition.
* **Autograd module** handles automatic differentiation.
* Integrates easily with **NumPy** and supports **CUDA (GPU)**.
* Used for cutting-edge research: NLP, CV, GANs, RL.
* Supports **TorchVision** (datasets, models) and **TorchAudio** (speech tasks).

**Code relation:** You verified version and GPU support using:

```python
torch.cuda.is_available()
```

This checks if PyTorch can utilize GPU acceleration.

---

## 🔹 DISTINCT FEATURES & COMPARISON

| Feature     | TensorFlow           | Keras                      | Theano          | PyTorch               |
| ----------- | -------------------- | -------------------------- | --------------- | --------------------- |
| Developer   | Google Brain         | François Chollet (Google)  | MILA (Montreal) | Facebook FAIR         |
| Year        | 2015                 | 2015                       | 2008            | 2016                  |
| Type        | Low to mid-level     | High-level                 | Low-level       | Low-level             |
| Graph Type  | Static               | Uses backend (static)      | Static          | Dynamic               |
| GPU Support | Yes                  | Yes (via backend)          | Yes             | Yes                   |
| Backend     | C++, CUDA            | TensorFlow                 | C / CUDA        | C++ / CUDA            |
| Debugging   | Harder               | Simple                     | Complex         | Very easy             |
| Ease of Use | Moderate             | Very easy                  | Difficult       | Easy                  |
| Best For    | Deployment           | Prototyping                | Academic        | Research              |
| Libraries   | TensorBoard, TF Lite | Sequential, Functional API | Symbolic math   | Autograd, TorchVision |
| Status      | Active               | Active                     | Discontinued    | Active                |

---

## 🔹 FUNCTIONALITY SUMMARY

| Functionality                 | Description                                              |
| ----------------------------- | -------------------------------------------------------- |
| **Model Definition**          | Create neural network layers, loss functions, optimizers |
| **Training and Evaluation**   | Train models using datasets and compute accuracy/loss    |
| **Automatic Differentiation** | Compute gradients automatically (Autograd / Symbolic)    |
| **GPU/TPU Acceleration**      | Speed up computation                                     |
| **Visualization**             | TensorBoard (TF), Visdom (PyTorch)                       |
| **Deployment**                | TensorFlow Lite, TorchScript, ONNX formats               |
| **Data Handling**             | Built-in datasets (Keras, TorchVision)                   |

---

## 🔹 EXPECTED VIVA QUESTIONS & ANSWERS

### **Basic**

**Q1:** What are deep learning packages?
**A:** They are libraries that simplify the implementation of neural networks by providing prebuilt modules for layers, optimizers, activation functions, and automatic differentiation.

**Q2:** Which package did you use to load the MNIST dataset?
**A:** Keras, using `datasets.mnist.load_data()`.

**Q3:** What is the difference between TensorFlow and PyTorch?
**A:** TensorFlow uses static graphs and is better for deployment, while PyTorch uses dynamic graphs and is preferred for research and experimentation.

---

### **Intermediate**

**Q4:** Why do we use GPU in deep learning?
**A:** GPUs handle parallel matrix computations efficiently, drastically reducing training time.

**Q5:** What is TensorBoard used for?
**A:** For visualizing training progress like loss curves, accuracy, and computation graphs in TensorFlow.

**Q6:** What does `torch.cuda.is_available()` return?
**A:** It returns `True` if GPU is available and PyTorch can utilize it; otherwise `False`.

---

### **Advanced**

**Q7:** Why is Keras called a high-level API?
**A:** Because it abstracts away low-level details and allows users to build models easily using simple Python code.

**Q8:** What did Theano contribute historically?
**A:** It introduced symbolic computation, automatic differentiation, and GPU acceleration concepts that shaped modern frameworks.

**Q9:** Which framework is most suitable for production?
**A:** TensorFlow, because it supports TensorFlow Lite, TensorFlow Serving, and model deployment pipelines.

**Q10:** Which is better for research and why?
**A:** PyTorch, because its dynamic graph and Pythonic nature allow flexible experimentation and debugging.

---

## 🔹 CONCLUSION

In this practical, we explored four major deep learning frameworks — TensorFlow, Keras, Theano, and PyTorch.
Each provides tools for developing, training, and deploying deep learning models.
TensorFlow excels in scalability and deployment, Keras simplifies model building, Theano laid the foundation for modern frameworks, and PyTorch dominates research with dynamic graphs.


'''
